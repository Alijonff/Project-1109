# %%
import pandas as pd

# %%
df = pd.read_excel('dataset.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   n                             730 non-null    int64
#  1   m                             730 non-null    int64
#  2   Routing function              730 non-null    object
#  3   Virtual channels number       730 non-null    int64
#  4   Virtual chanel buffer size    730 non-null    int64
#  5   Optimal data generation rate  730 non-null    float64
#  6   Optimal throughput value      730 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 40.0+ KB

# %%
df.loc[df['Routing function'] == 'dim_order', 'Routing function'] = 1
df.loc[df['Routing function'] == 'dor', 'Routing function'] = 0

# %%
df = df.astype({'Routing function': int})

# %%
df
# Out:
#      n  m  Routing function  Virtual channels number  \
# 0    2  1                 1                        1
# 1    2  1                 1                        1
# 2    2  1                 1                        1
# 3    2  1                 1                        1
# 4    2  1                 1                        2
# ..  .. ..               ...                      ...
# 725  9  2                 0                        3
# 726  9  2                 0                        4
# 727  9  2                 0                        4
# 728  9  2                 0                        4
# 729  9  2                 0                        4
#
#      Virtual chanel buffer size  Optimal data generation rate  \
# 0                             1                          0.30
# 1                             2                          0.50
# 2                             3                          0.90
# 3                             4                          1.10
# ...

# %%
df.to_csv('dataset2.csv', index=False)
